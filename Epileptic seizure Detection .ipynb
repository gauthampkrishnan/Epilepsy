# %%
ls
# Out:
# 'Epileptic seizure Detection .ipynb'   imp.csv   README.md

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df=pd.read_csv("imp.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
df=pd.read_csv("imp.csv",header=0,index_col=0)

# %%
df.head()
# Out:
#              X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X170  X171  \
# X21.V1.791  135  190  229  223  192  125   55   -9  -33  -38  ...   -17   -15
# X15.V1.924  386  382  356  331  320  315  307  272  244  232  ...   164   150
# X8.V1.1     -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    57    64
# X16.V1.60  -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -82   -81
# X20.V1.54    -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     4     2
#
#             X172  X173  X174  X175  X176  X177  X178  y
# X21.V1.791   -31   -77  -103  -127  -116   -83   -51  4
# X15.V1.924   146   152   157   156   154   143   129  1
# X8.V1.1       48    19   -12   -30   -35   -35   -36  5
# X16.V1.60    -80   -77   -85   -77   -72   -69   -65  5
# X20.V1.54    -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 179 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11500 entries, X21.V1.791 to X16.V1.210
# Columns: 179 entries, X1 to y
# dtypes: int64(179)
# memory usage: 15.8+ MB

# %%
df["seizure"]=0
for i in range(11500):
    if df["y"][i] == 1:
        df["seizure"][i] = 1
    else:
        df["seizure"][i] = 0

# %%
print(df["seizure"])
# Therefore there are 11500 outputs
# Out:
# X21.V1.791    0
# X15.V1.924    1
# X8.V1.1       0
# X16.V1.60     0
# X20.V1.54     0
#              ..
# X22.V1.114    0
# X19.V1.354    1
# X8.V1.28      0
# X10.V1.932    0
# X16.V1.210    0
# Name: seizure, Length: 11500, dtype: int64

# %%
print(df["seizure"][0])
# 0 means non epileptic
# Out:
# 0

# %%
print(df["seizure"][1])
# 1 means Epileptic
# Out:
# 1

# %%
plt.plot(range(178),df.iloc[0,0:178])
plt.show()
# Non Epileptic Waveform

# %%
plt.plot(range(178), df.iloc[1,0:178])
plt.show()
# Epileptic Waveform

# %%
# Plotted 20 samples for exploratory process.
# With the label as 0 or 1 .
for i in range(20,40):
    plt.plot(range(178),df.iloc[i,0:178])
    plt.title(df["seizure"][i])
    plt.show()

# %%
df.head()
# Out:
#              X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X171  X172  \
# X21.V1.791  135  190  229  223  192  125   55   -9  -33  -38  ...   -15   -31
# X15.V1.924  386  382  356  331  320  315  307  272  244  232  ...   150   146
# X8.V1.1     -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    64    48
# X16.V1.60  -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -81   -80
# X20.V1.54    -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     2   -12
#
#             X173  X174  X175  X176  X177  X178  y  seizure
# X21.V1.791   -77  -103  -127  -116   -83   -51  4        0
# X15.V1.924   152   157   156   154   143   129  1        1
# X8.V1.1       19   -12   -30   -35   -35   -36  5        0
# X16.V1.60    -77   -85   -77   -72   -69   -65  5        0
# X20.V1.54    -32   -41   -65   -83   -89   -73  5        0
#
# [5 rows x 180 columns]

# %%
# Remove the seizure coloumn from the original dataset
df_original = df.drop(["seizure", "y"], axis=1)

# %%
df_original.head()
# Out:
#              X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...  X169  X170  \
# X21.V1.791  135  190  229  223  192  125   55   -9  -33  -38  ...     8   -17
# X15.V1.924  386  382  356  331  320  315  307  272  244  232  ...   168   164
# X8.V1.1     -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...    29    57
# X16.V1.60  -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...   -80   -82
# X20.V1.54    -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...    10     4
#
#             X171  X172  X173  X174  X175  X176  X177  X178
# X21.V1.791   -15   -31   -77  -103  -127  -116   -83   -51
# X15.V1.924   150   146   152   157   156   154   143   129
# X8.V1.1       64    48    19   -12   -30   -35   -35   -36
# X16.V1.60    -81   -80   -77   -85   -77   -72   -69   -65
# X20.V1.54      2   -12   -32   -41   -65   -83   -89   -73
#
# [5 rows x 178 columns]

# %%
# Normalising the data to the range of 0 to 1 
# Using the formula (x-mu)/sigma
# Where x = real data, mu is the mean, sigma is standard deviation

# %%
mean = df_original.mean(axis=0)
print(mean)
# Out:
# X1     -11.581391
# X2     -10.911565
# X3     -10.187130
# X4      -9.143043
# X5      -8.009739
#           ...
# X174   -13.363304
# X175   -13.045043
# X176   -12.705130
# X177   -12.426000
# X178   -12.195652
# Length: 178, dtype: float64

# %%
df_original -= mean
print(df_original)
# Out:
#                     X1          X2         X3          X4          X5  \
# X21.V1.791  146.581391  200.911565  239.18713  232.143043  200.009739
# X15.V1.924  397.581391  392.911565  366.18713  340.143043  328.009739
# X8.V1.1     -20.418609  -28.088435  -36.81287  -27.856957  -23.990261
# X16.V1.60   -93.418609  -90.088435  -85.81287  -82.856957  -80.990261
# X20.V1.54     2.581391  -54.088435  -87.81287  -92.856957  -69.990261
# ...                ...         ...        ...         ...         ...
# X22.V1.114  -10.418609  -11.088435  -12.81287  -16.856957  -27.990261
# X19.V1.354  -35.418609   -0.088435   38.18713   86.143043  149.009739
# X8.V1.28     25.581391   16.911565   -2.81287   -6.856957   18.009739
# X10.V1.932  -28.418609  -14.088435    1.18713   -2.856957    6.009739
# X16.V1.210   40.581391   51.911565   67.18713   81.143043   82.009739
#
#                     X6          X7         X8       X9         X10  ...  \
# ...

# %%
std = df_original.std(axis=0)
print(std)
# Out:
# X1      165.626284
# X2      166.059609
# X3      163.524317
# X4      161.269041
# X5      160.998007
#            ...
# X174    167.257290
# X175    164.241019
# X176    162.895832
# X177    162.886311
# X178    164.852015
# Length: 178, dtype: float64

# %%
df_original /= std
print(df_original)
# Out:
#                   X1        X2        X3        X4        X5        X6  \
# X21.V1.791  0.005343  0.007286  0.008945  0.008926  0.007716  0.005072
# X15.V1.924  0.014493  0.014248  0.013694  0.013079  0.012655  0.012372
# X8.V1.1    -0.000744 -0.001019 -0.001377 -0.001071 -0.000926 -0.001114
# X16.V1.60  -0.003405 -0.003267 -0.003209 -0.003186 -0.003125 -0.003381
# X20.V1.54   0.000094 -0.001961 -0.003284 -0.003570 -0.002700 -0.001575
# ...              ...       ...       ...       ...       ...       ...
# X22.V1.114 -0.000380 -0.000402 -0.000479 -0.000648 -0.001080 -0.001345
# X19.V1.354 -0.001291 -0.000003  0.001428  0.003312  0.005749  0.008376
# X8.V1.28    0.000933  0.000613 -0.000105 -0.000264  0.000695  0.001268
# X10.V1.932 -0.001036 -0.000511  0.000044 -0.000110  0.000232  0.000730
# X16.V1.210  0.001479  0.001883  0.002513  0.003120  0.003164  0.002651
#
#                   X7        X8        X9       X10  ...      X169      X170  \
# ...

# %%
target = df["seizure"].values

# %%
target
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from keras.models import Sequential
from keras import layers
from keras import regularizers
model = Sequential()
model.add(layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l1(0.001), input_shape = (178,)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(64, activation="relu", kernel_regularizer=regularizers.l1(0.001)))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 64)                11456
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# ...
# Total params: 15,681
# Trainable params: 15,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
# There are 15,681 parameters

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df_original, target, test_size=0.2, random_state=42)

# %%
model.compile(optimizer="rmsprop", loss="binary_crossentropy", metrics=["acc"])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=128, validation_split=0.2, verbose=2)
# Out:
# Train on 7360 samples, validate on 1840 samples
# Epoch 1/100
#  - 2s - loss: 36.8980 - acc: 0.5371 - val_loss: 8.9620 - val_acc: 0.7766
# Epoch 2/100
#  - 0s - loss: 19.6941 - acc: 0.5781 - val_loss: 4.9153 - val_acc: 0.7859
# Epoch 3/100
#  - 0s - loss: 12.3735 - acc: 0.5988 - val_loss: 3.1996 - val_acc: 0.8060
# Epoch 4/100
#  - 0s - loss: 7.1501 - acc: 0.6026 - val_loss: 2.2259 - val_acc: 0.8043
# Epoch 5/100
#  - 0s - loss: 3.9573 - acc: 0.6364 - val_loss: 1.8920 - val_acc: 0.8250
# Epoch 6/100
#  - 0s - loss: 2.6213 - acc: 0.6990 - val_loss: 1.7793 - val_acc: 0.8582
# Epoch 7/100
#  - 0s - loss: 2.0679 - acc: 0.7607 - val_loss: 1.7240 - val_acc: 0.8380
# Epoch 8/100
#  - 0s - loss: 1.8011 - acc: 0.8132 - val_loss: 1.6437 - val_acc: 0.8527
# Epoch 9/100
#  - 0s - loss: 1.6775 - acc: 0.8380 - val_loss: 1.5454 - val_acc: 0.8859
# Epoch 10/100
#  - 0s - loss: 1.5631 - acc: 0.8580 - val_loss: 1.4562 - val_acc: 0.9011
# Epoch 11/100
# ...

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']

# %%
plt.plot( loss_train, 'g', label='Training loss')
plt.plot( loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
print(history.history['acc'][99])
# Out:
# 0.9605978

# %%
# We are getting accuracy of about 96% with using dense neural network.
